# %%
import pandas as pd
import numpy as np
# %matplotlib inline

# %%
products = pd.read_csv('products-2.csv', sep='\t')

# %%
product.shape #returns a tuple of the number of rows and columns
# Out:
# (504, 25)

# %%
#print a list of all the columns
products.columns
# Out:
# Index(['ProductID', 'Name', 'ProductNumber', 'MakeFlag', 'FinishedGoodsFlag',
#        'Color', 'SafetyStockLevel', 'ReorderPoint', 'StandardCost',
#        'ListPrice', 'Size', 'SizeUnitMeasureCode', 'WeightUnitMeasureCode',
#        'Weight', 'DaysToManufacture', 'ProductLine', 'Class', 'Style',
#        'ProductSubcategoryID', 'ProductModelID', 'SellStartDate',
#        'SellEndDate', 'DiscontinuedDate', 'rowguid', 'ModifiedDate'],
#       dtype='object')

# %%
#first 5 rows
products.head()
# Out:
#    ProductID                   Name ProductNumber  MakeFlag  \
# 0          1        Adjustable Race       AR-5381         0
# 1          2           Bearing Ball       BA-8327         0
# 2          3        BB Ball Bearing       BE-2349         1
# 3          4  Headset Ball Bearings       BE-2908         0
# 4        316                  Blade       BL-2036         1
#
#    FinishedGoodsFlag Color  SafetyStockLevel  ReorderPoint  StandardCost  \
# 0                  0   NaN              1000           750           0.0
# 1                  0   NaN              1000           750           0.0
# 2                  0   NaN               800           600           0.0
# 3                  0   NaN               800           600           0.0
# 4                  0   NaN               800           600           0.0
#
#    ListPrice              ...               ProductLine Class Style  \
# 0        0.0              ...                       NaN   NaN   NaN
# ...

# %%
#last 5 rows
products.tail()
# Out:
#      ProductID               Name ProductNumber  MakeFlag  FinishedGoodsFlag  \
# 499        995  ML Bottom Bracket       BB-8107         1                  1
# 500        996  HL Bottom Bracket       BB-9108         1                  1
# 501        997  Road-750 Black 44    BK-R19B-44         1                  1
# 502        998  Road-750 Black 48    BK-R19B-48         1                  1
# 503        999  Road-750 Black 52    BK-R19B-52         1                  1
#
#      Color  SafetyStockLevel  ReorderPoint  StandardCost  ListPrice  \
# 499    NaN               500           375       44.9506     101.24
# 500    NaN               500           375       53.9416     121.49
# 501  Black               100            75      343.6496     539.99
# 502  Black               100            75      343.6496     539.99
# 503  Black               100            75      343.6496     539.99
#
#                  ...               ProductLine Class Style  \
# ...

# %%
products.shape[0] #prints how many rows
# Out:
# 504

# %%
products.index #display the index as it was imported
# Out:
# RangeIndex(start=0, stop=504, step=1)

# %%
#if your data sheet has its own numbers that is in order, you can replace the numbers that pandas automatically 
#generates for you
products.set_index('ProductID', inplace=True)

# %%
products.head(100) #you can display how many you want with a number in the brackets
# Out:
#                               Name ProductNumber  MakeFlag  FinishedGoodsFlag  \
# ProductID
# 1                  Adjustable Race       AR-5381         0                  0
# 2                     Bearing Ball       BA-8327         0                  0
# 3                  BB Ball Bearing       BE-2349         1                  0
# 4            Headset Ball Bearings       BE-2908         0                  0
# 316                          Blade       BL-2036         1                  0
# 317                    LL Crankarm       CA-5965         0                  0
# 318                    ML Crankarm       CA-6738         0                  0
# 319                    HL Crankarm       CA-7457         0                  0
# 320                Chainring Bolts       CB-2903         0                  0
# 321                  Chainring Nut       CN-6137         0                  0
# 322                      Chainring       CR-7833         0                  0
# ...

# %%
#display the data types of the columns
products.dtypes
# Out:
# Name                      object
# ProductNumber             object
# MakeFlag                   int64
# FinishedGoodsFlag          int64
# Color                     object
# SafetyStockLevel           int64
# ReorderPoint               int64
# StandardCost             float64
# ListPrice                float64
# Size                      object
# SizeUnitMeasureCode       object
# WeightUnitMeasureCode     object
# Weight                   float64
# DaysToManufacture          int64
# ProductLine               object
# Class                     object
# Style                     object
# ProductSubcategoryID     float64
# ProductModelID           float64
# SellStartDate             object
# SellEndDate               object
# DiscontinuedDate         float64
# rowguid                   object
# ModifiedDate              object
# dtype: object

# %%
#the difference between using double vs single square brackets when selecting columns
#products['Name'].head(10) #displays it a series
products[['Name']].head(10) #displays it a DataFrame use this when you want a total or median/average etc..
# Out:
#                             Name
# ProductID
# 1                Adjustable Race
# 2                   Bearing Ball
# 3                BB Ball Bearing
# 4          Headset Ball Bearings
# 316                        Blade
# 317                  LL Crankarm
# 318                  ML Crankarm
# 319                  HL Crankarm
# 320              Chainring Bolts
# 321                Chainring Nut

# %%
#select the name column, return it as a Series object
products['Name'].head(10)
# Out:
# ProductID
# 1            Adjustable Race
# 2               Bearing Ball
# 3            BB Ball Bearing
# 4      Headset Ball Bearings
# 316                    Blade
# 317              LL Crankarm
# 318              ML Crankarm
# 319              HL Crankarm
# 320          Chainring Bolts
# 321            Chainring Nut
# Name: Name, dtype: object

# %%
#select the name of the column, return it as a DataFrame object
products[['Name']].head(10)
# Out:
#                             Name
# ProductID
# 1                Adjustable Race
# 2                   Bearing Ball
# 3                BB Ball Bearing
# 4          Headset Ball Bearings
# 316                        Blade
# 317                  LL Crankarm
# 318                  ML Crankarm
# 319                  HL Crankarm
# 320              Chainring Bolts
# 321                Chainring Nut

# %%
#rename all the columns with a new list of column name

# %%
#display descriptive statistics of dataset (only columns with numbers)
products.describe()[['Weight', 'ListPrice']]
#products.describe()[['Weight', 'ListPrice']] can choose specific columns with the describe function
# Out:
#             Weight    ListPrice
# count   205.000000   504.000000
# mean     74.069220   438.666250
# std     182.166588   773.602843
# min       2.120000     0.000000
# 25%       2.880000     0.000000
# 50%      17.900000    49.990000
# 75%      27.350000   564.990000
# max    1050.000000  3578.270000

# %%
#show the most popular product colours (aggregated by count, decending by default)
products['Color'].value_counts() #value counts is a series
# Out:
# Black           93
# Silver          43
# Red             38
# Yellow          36
# Blue            26
# Multi            8
# Silver/Black     7
# White            4
# Grey             1
# Name: Color, dtype: int64

# %%
#what are the unique colours for the products?
#products['Color'].unique()
products['Color'].nunique() #total amount of colours
# Out:
# 9

# %%
#find all the products that are black
products[products['Color'] == 'Black']
#products[products['Color'] == 'Black']['Color'].value_counts() #find the total for the specific color
# Out:
#                                    Name ProductNumber  MakeFlag  \
# ProductID
# 317                         LL Crankarm       CA-5965         0
# 318                         ML Crankarm       CA-6738         0
# 319                         HL Crankarm       CA-7457         0
# 322                           Chainring       CR-7833         0
# 680            HL Road Frame - Black 58    FR-R92B-58         1
# 708              Sport-100 Helmet Black       HL-U509         0
# 722            LL Road Frame - Black 58    FR-R38B-58         1
# 723            LL Road Frame - Black 60    FR-R38B-60         1
# 724            LL Road Frame - Black 62    FR-R38B-62         1
# 736            LL Road Frame - Black 44    FR-R38B-44         1
# 737            LL Road Frame - Black 48    FR-R38B-48         1
# 738            LL Road Frame - Black 52    FR-R38B-52         1
# 743        HL Mountain Frame - Black 42    FR-M94B-42         1
# ...

# %%
#calculate the average list price of the saleable products
products[products['FinishedGoodsFlag'] == 1]['ListPrice'].mean()
#get the minimum list price
#products[products['FinishedGoodsFlag'] == 1]['ListPrice'].min()
#get the max list price
#products[products['FinishedGoodsFlag'] == 1]['ListPrice'].max()
# Out:
# 744.595220338982

# %%
#data[data['FinishedGoodsFlag'] == 1]['ListPrice'].hist(grid=False, bins=10)

# %%
#plot a histogram of the listprices of items where finishedgoodsflag = 1
products[products['FinishedGoodsFlag'] == 1]['ListPrice'].hist()#(grid=False, bins=10)

# %%
products[products['FinishedGoodsFlag'] == 1]['ListPrice'].hist(grid=False, bins=10)
